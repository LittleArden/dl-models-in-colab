# %% [markdown]
# <a href="https://colab.research.google.com/github/LittleArden/dl-models-in-colab/blob/main/MMSA_FET_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 安装python3.8
# MMSA-FET是基于python3.8构建的，而colab只内置了3.6与3.7版本，故需要先安装python3.8版本。

# %%
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py38" --user
# Out:
# --2022-05-06 01:50:07--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89817099 (86M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  85.66M  83.7MB/s    in 1.0s
#
# 2022-05-06 01:50:08 (83.7 MB/s) - ‘mini.sh’ saved [89817099/89817099]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py38_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py38_0
#     - cffi==1.14.0=py38h2e261b9_0
#     - chardet==3.0.4=py38_1003
#     - conda-package-handling==1.6.0=py38h7b6447c_0
# ...

# %% [markdown]
# **安装后刷新页面**

# %%
# Reload the web page and execute this cell
import sys
print("User Current Version:-", sys.version)
# Out:
# User Current Version:- 3.8.1 (default, Jan  8 2020, 22:29:32)
# [GCC 7.3.0]

# %% [markdown]
# # MMSA-FTL

# %%
# !git clone https://github.com/thuiar/MMSA-FET.git
# Out:
# Cloning into 'MMSA-FET'...
# remote: Enumerating objects: 624, done.
# remote: Counting objects: 100% (624/624), done.
# remote: Compressing objects: 100% (288/288), done.
# remote: Total 624 (delta 286), reused 624 (delta 286), pack-reused 0
# Receiving objects: 100% (624/624), 24.84 MiB | 27.20 MiB/s, done.
# Resolving deltas: 100% (286/286), done.

# %%
# Install package from PyPI
! pip install MMSA-FET
# Out:
# ...
#      |████████████████████████████████| 64 kB 135 kB/s
# ...
#      |████████████████████████████████| 78 kB 160 kB/s
# ...
#      |████████████████████████████████| 98 kB 96 kB/s
# ...
#      |████████████████████████████████| 11.7 MB 92 kB/s
# ...
#      |████████████████████████████████| 213 kB 96 kB/s
# ...
#      |████████████████████████████████| 32.9 MB 86 kB/s
# ...
#      |████████████████████████████████| 4.5 MB 351 kB/s
# ...
#      |████████████████████████████████| 4.0 MB 398 kB/s
# ...
#      |████████████████████████████████| 750.6 MB 18 kB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 41.6 MB 102 kB/s
# ...
#      |████████████████████████████████| 66.7 MB 33 kB/s
# ...
#      |████████████████████████████████| 96 kB 3.9 MB/s
# ...
#      |████████████████████████████████| 377 kB 817 kB/s
# ...
#      |████████████████████████████████| 26.7 MB 1.8 MB/s
# ...
#      |████████████████████████████████| 56 kB 273 kB/s
# ...

# %%
# Download models & libraries from Google Drive. Use --proxy if needed.
! python -m MSA_FET install
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=17T1WSbkwBokTqNq1IKu51oMX8P122pu-
# To: /usr/local/lib/python3.8/site-packages/MSA_FET/exts/OpenFace_Base.zip
# 100% 427M/427M [00:03<00:00, 136MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Y-WX9xoCYVQqy-VYXyA3697RCiSAldml
# To: /usr/local/lib/python3.8/site-packages/MSA_FET/exts/OpenFace/OpenFace_Linux.zip
# 100% 783k/783k [00:00<00:00, 55.3MB/s]
# Done.
# Downloading...
# From: https://drive.google.com/uc?id=1Yzetew3mRjQqhhHLsZP1uT6zT9lR_DOG
# To: /usr/local/lib/python3.8/site-packages/MSA_FET/exts/pretrained.zip
# 100% 142M/142M [00:01<00:00, 138MB/s]

# %%
import os
path = '/content/MMSA-FET/src/MSA_FET'
os.chdir(path)
os.listdir(path)
# Out:
# ['__main__.py',
#  '.ipynb_checkpoints',
#  'ASD',
#  'utils.py',
#  '__init__.py',
#  'main.py',
#  '9.mp4',
#  'install.py',
#  'dataloader.py',
#  'extractors',
#  'models',
#  'example_configs']

# %%
from MSA_FET import FeatureExtractionTool

# initialize with default librosa config which only extracts audio features
fet = FeatureExtractionTool("librosa")
# alternatively initialize with a custom config file
# fet = FeatureExtractionTool("custom_config.json")
# Out:
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# ...

# %%
import ffmpeg

# %%
# extract features for single video
feature = fet.run_single("9.mp4")
print(feature)
# Out:
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# ...

# %%
from MSA_FET import FeatureExtractionTool

#fet = FeatureExtractionTool(config="bert")
fet = FeatureExtractionTool(config="openface")
feature = fet.run_single("9.mp4")
print(feature)
# Out:
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET -
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# MMSA-FET - ========================== MMSA-FET Started ==========================
# ...

# %%
# extract for dataset & save features to file
feature = fet.run_dataset(dataset_dir="~/MOSI", out_file="output/feature.pkl")
# Out:
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Initializing librosa audio feature extractor.
# MMSA-FET - Extracting features from 'input.mp4'.
# MMSA-FET - Extracting features from 'input.mp4'.
# MMSA-FET - An Error Occured:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/MSA_FET/main.py", line 303, in run_single
#     audio_result = self.__audio_extract_single(in_file, keep_tmp_file=True)
#   File "/usr/local/lib/python3.8/site-packages/MSA_FET/main.py", line 140, in __audio_extract_single
#     ffmpeg_extract(in_file, tmp_audio_file, mode='audio')
#   File "/usr/local/lib/python3.8/site-packages/MSA_FET/utils.py", line 63, in ffmpeg_extract
#     ffmpeg.input(in_file).output(out_path)\
#   File "/usr/local/lib/python3.8/site-packages/ffmpeg/_run.py", line 325, in run
#     raise Error('ffmpeg', out, err)
# ffmpeg._run.Error: ffmpeg error (see stderr output for detail)
# MMSA-FET - An Error Occured:
# ...
